# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd = pd.read_csv('../data/DataProcess/真实值与预测值2.csv')
true = pd['真实值']
pred = pd['预测值']
# 画图展示
plt.figure(figsize=(10, 5))
plt.plot(true, label='true')
plt.plot(pred, label='pred')
plt.legend()
plt.show()

# %%
# 计算误差 MAE
mae = np.mean(np.abs(true - pred))
print('MAE:', mae)
# 计算R^2
r2 = 1 - np.sum((true - pred) ** 2) / np.sum((true - np.mean(true)) ** 2)
print('R^2:', r2)
# Out:
# MAE: 20.494749573275683
# R^2: 0.4099872672162832
